# %%
import sys
print(sys.version)          # Python na compute
print(spark.version)        # Spark verzia
spark.sql("SELECT current_version()").show(truncate=False)
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# 4.1.0
# +-----------------------------------------------------------------------------------------------------------------+
# |current_version()                                                                                                |
# +-----------------------------------------------------------------------------------------------------------------+
# |{18.x-photon-scala2.13, NULL, bfd1bbfb31c2a1612dbe11f74693242f732a7d8e, b0356d334ed123c90bb1c1c89d14dabbbf60f18d}|
# +-----------------------------------------------------------------------------------------------------------------+
